# %% [markdown]
# #### **1. Contexto de negocio**
#
# El nomadismo digital ha crecido de forma acelerada, pero no todos los destinos son igual de atractivos para este perfil.
#
# Elegir un destino depende de una ponderación entre:
#
# - Coste de vida
# - Infraestructura digital
# - Calidad de vida
# - Capacidad económica local (salarios vs precios)
# - Accesibilidad urbana
#
# Desde negocio, esto impacta en:
#
# - Plataformas de relocación
# - Marketplaces para nómadas digitales
# - Inmobiliarias internacionales
# - Gobiernos / city branding
# - Empresas que diseñan productos para trabajadores remotos

# %% [markdown]
# #### **2. Problema general a resolver con el EDA**
#
# ¿Qué características económicas y de coste de vida diferencian a los países y ciudades mejor posicionados para el nomadismo digital frente a los menos atractivos?
#
# 1. ¿Son realmente más baratos los destinos mejor rankeados para nómadas digitales?
# 2. ¿El coste de vivienda es el principal factor diferenciador entre unos destinos y otros?
# 3. ¿Existe coherencia entre salarios locales y precios de productos esenciales?
# 4. ¿Hay “outliers” atractivos (alta calidad de vida / coste moderado)?
# 5. ¿Qué tipo de gasto pesa más en la viabilidad del nomadismo digital?

# %% [markdown]
# #### **3. Definición de variables clave**
#
# Una de las claves para el EDA no sólo es el análisis univariante, bivariante y multivariante de las variables de los dataset disponibles.
#
# **Pensamos que el cálculo de variables agregadas a partir de las variables disponibles puede ser clave**
#
# ##### **Dataset [Digital Nomad Index Movingto](https://www.movingto.com/digital-nomad-index)** ✅ ETL Completado
#
# **Estado:** Dataset limpio disponible en `digital-nomad-index-movingto-clean.csv`
#
# | Característica | Valor |
# |----------------|-------|
# | Filas | 40 países |
# | Columnas | 10 |
# | Fuente | movingto.com |
#
# **Columnas finales (tras ETL):**
#
# | Columna | Tipo | Descripción |
# |---------|------|-------------|
# | `rank` | int | Posición en el ranking (1-40) |
# | `country` | str | Nombre del país (estandarizado) |
# | `overall_score` | int | Puntuación global (0-100) |
# | `internet_speed` | int | Score de velocidad internet (0-100) |
# | `cost_of_living` | int | Score coste de vida (0-100, mayor = más barato) |
# | `safety` | int | Score de seguridad (0-100) |
# | `visa_ease` | int | Score facilidad de visa (0-100) |
# | `quality_of_life` | int | Score calidad de vida (0-100) |
# | `taxes` | str | Rango impositivo (texto) |
# | `tax_free_period` | str | Período libre de impuestos (texto) |
#
# **Transformaciones aplicadas:**
# - Renombrado columnas a snake_case
# - Corrección: "Bali, Indonesia" → "Indonesia"
# - Verificación de nulos (0 encontrados)
#
# **Variables únicas de este dataset:**
# - `safety` — No disponible en otros datasets
# - `visa_ease` — No disponible en otros datasets
# - `taxes` / `tax_free_period` — Información fiscal cualitativa
#
# **Muestra de datos originales:**
#
# | Rank | Country        | Overall | Internet Speed | Cost of Living | Safety | Visa Ease | Quality of Life | Taxes    | Tax-free Period |
# |------|----------------|---------|----------------|----------------|--------|-----------|-----------------|----------|-----------------|
# | 1    | Portugal       | 92      | 90             | 85             | 95     | 95        | 95              | NHR 20%  | 10 years        |
# | 2    | Estonia        | 91      | 95             | 75             | 90     | 98        | 92              | 0-20%    | 183 days/year   |
# | 3    | Georgia        | 90      | 85             | 88             | 82     | 100       | 80              | 1%       | 183 days/year   |
# | 4    | Spain          | 89      | 88             | 80             | 92     | 92        | 94              | 24%      | 183 days/year   |
# | 5    | Thailand       | 88      | 85             | 95             | 80     | 90        | 88              | 0-35%    | 183 days/year   |
#
#
# ##### **Dataset [Digital Nomad Index](https://www.movingto.com/digital-nomad-index)**
#
# Variables típicas (dependiendo del índice):
#
# - Ranking o score global
# - Internet / infraestructura
# - Seguridad
# - Calidad de vida
# - Coste relativo
# - Clima
# - Visados / facilidad legal
#
# Variable objetivo implícita:
#
# > digital_nomad_score o ranking
#
# Selección de muestra de variables:
#
# | Rank           | Country        | Overall  | Internet Speed | Cost of Living | Safety   | Visa Ease  | Quality of Life | Taxes    | Tax-free Period |
# | -------------- | -------------- | -------- | -------------- | -------------  | -------- | ---------- | --------------- | -------- | --------------- |
# | 1              | Portugal       | 92       | 90             | 85             | 95       | 95         | 95              | NHR 20%  | 10 years        |
# | 2              | Estonia        | 91       | 95             | 75             | 90       | 98         | 92              | 0-20%    | 183 days/year   |
# | 3              | Georgia        | 90       | 85             | 88             | 82       | 100        | 80              | 1%       | 183 days/year   |
# | 4              | Spain          | 89       | 88             | 80             | 92       | 92         | 94              | 24%      | 183 days/year   |
# | 5              | Thailand       | 88       | 85             | 95             | 80       | 90         | 88              | 0-35%    | 183 days/year   |
# | 6              | México         | 87       | 82             | 90             | 75       | 94         | 86              | 1.92-35% | 183 days/year   |
# | 7              | Czech Republic | 86       | 87             | 78             | 88       | 85         | 90              | 15%      | 183 days/year   |
# | 8              | Malaysia       | 85       | 80             | 92             | 85       | 90         | 85              | 0-30%    | 182 days/year   |
# | 9              | Croatia        | 84       | 76             | 88             | 88       | 89         |                 | 24%      | 1 year          |
# | 10             | Costa Rica     | 83       | 79             | 85             | 80       | 90         | 88              | 0-25%    | 183 days/year   |
#
#
# ##### **Dataset [Cost of Living](https://www.kaggle.com/datasets/mvieira101/global-cost-of-living/code)** ✅ ETL Completado
#
# Agrupamiento de variables para el análisis multivariante posterior. Y clave en el cálculos de variables agregadas.
#
# 🏠 **1. Vivienda**
#
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x48          | Apartamento (1 dormitorio) en el centro de la ciudad (USD)                                                         |
# | x49          | Apartamento (1 dormitorio) fuera del centro (USD)                                                                  |
# | x50          | Apartamento (3 dormitorios) en el centro de la ciudad (USD)                                                        |
# | x51          | Apartamento (3 dormitorios) fuera del centro (USD)                                                                 |
# | x52          | Precio por metro cuadrado para comprar apartamento en el centro (USD)                                              |
# | x53          | Precio por metro cuadrado para comprar apartamento fuera del centro (USD)                                          |
#
# ---
#
# 🍽️ **2. Coste diario**
#
# - Restaurantes
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ---------------------------------------------------------------------------------------------------------------- |
# | x1           | Comida en restaurante económico (USD)                                                                              |
# | x2           | Comida para 2 personas en restaurante de gama media, tres platos (USD)                                             |
# | x3           | Menú McMeal en McDonald’s (o menú equivalente) (USD)                                                               |
# | x4           | Cerveza nacional (0,5 litros de barril, en restaurante) (USD)                                                      |
# | x5           | Cerveza importada (botella de 0,33 litros, en restaurante) (USD)                                                   |
# | x6           | Cappuccino (normal, en restaurante) (USD)                                                                          |
# | x7           | Coca-Cola / Pepsi (botella de 0,33 litros, en restaurante) (USD)                                                   |
# | x8           | Agua (botella de 0,33 litros, en restaurante) (USD)                                                                |
#
# - Supermercado
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ---------------------------------------------------------------------------------------------------------------- |
# | x9           | Leche (normal), 1 litro (USD)                                                                                      |
# | x10          | Barra de pan blanco fresco (500 g) (USD)                                                                           |
# | x11          | Arroz blanco (1 kg) (USD)                                                                                          |
# | x12          | Huevos (docena) (USD)                                                                                              |
# | x13          | Queso local (1 kg) (USD)                                                                                           |
# | x14          | Pechugas de pollo (1 kg) (USD)                                                                                     |
# | x15          | Carne de ternera (1 kg) o carne roja equivalente (USD)                                                             |
# | x16          | Manzanas (1 kg) (USD)                                                                                              |
# | x17          | Plátanos (1 kg) (USD)                                                                                              |
# | x18          | Naranjas (1 kg) (USD)                                                                                              |
# | x19          | Tomates (1 kg) (USD)                                                                                               |
# | x20          | Patatas (1 kg) (USD)                                                                                               |
# | x21          | Cebollas (1 kg) (USD)                                                                                              |
# | x22          | Lechuga (1 unidad) (USD)                                                                                           |
#
#
# 🚕 **3. Transporte**
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x28          | Billete de transporte público (solo ida) (USD)                                                                     |
# | x29          | Abono mensual de transporte (precio normal) (USD)                                                                  |
# | x30          | Bajada de bandera del taxi (tarifa normal) (USD)                                                                   |
# | x31          | Taxi por kilómetro (tarifa normal) (USD)                                                                           |
# | x32          | Taxi, 1 hora de espera (tarifa normal) (USD)                                                                       |
# | x33          | Gasolina (1 litro) (USD)                                                                                           |
#
#
# 🌐 **4. Infraestructura**
#
# - Internet
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x38          | Internet (60 Mbps o más, datos ilimitados, cable/ADSL) (USD)                                                       |
#
# - Utilities
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x36          | Gastos básicos (electricidad, calefacción, refrigeración, agua, basura) para apartamento de 85 m² (USD)            |
#
# 💰 **5. Capacidad económica**
#
# - Salario
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x54          | Salario mensual neto medio (después de impuestos) (USD)                                                            |
#
#
# - Interés hipotecario
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | x55          | Tipo de interés hipotecario anual (%), fijo a 20 años                                                              |
#
# 🟧 **6. Resto de variables**
#
# | Columna      | Descripción                                                                                                        |
# | ------------ | ------------------------------------------------------------------------------------------------------------------ |
# | city         | Nombre de la ciudad                                                                                                |
# | country      | Nombre del país                                                                                                    |
# | x23          | Agua (botella de 1,5 litros, en supermercado) (USD)                                                                |
# | x24          | Botella de vino de gama media (en supermercado) (USD)                                                              |
# | x25          | Cerveza nacional (botella de 0,5 litros, en supermercado) (USD)                                                    |
# | x26          | Cerveza importada (botella de 0,33 litros, en supermercado) (USD)                                                  |
# | x27          | Paquete de 20 cigarrillos (Marlboro) (USD)                                                                         |
# | x34          | Volkswagen Golf 1.4 90 KW Trendline (o coche nuevo equivalente) (USD)                                              |
# | x35          | Toyota Corolla Sedán 1.6l 97kW Comfort (o coche nuevo equivalente) (USD)                                           |
# | x37          | 1 minuto de tarifa móvil prepago local (sin descuentos ni planes) (USD)                                            |
# | x39          | Gimnasio, cuota mensual para 1 adulto (USD)                                                                        |
# | x40          | Alquiler de pista de tenis (1 hora en fin de semana) (USD)                                                         |
# | x41          | Cine, estreno internacional, 1 entrada (USD)                                                                       |
# | x42          | Guardería o preescolar privado, jornada completa, mensual por 1 niño (USD)                                         |
# | x43          | Colegio internacional de primaria, coste anual por 1 niño (USD)                                                    |
# | x44          | 1 par de vaqueros (Levis 501 o similar) (USD)                                                                      |
# | x45          | Vestido de verano en tienda de cadena (Zara, H&M o similar) (USD)                                                  |
# | x46          | 1 par de zapatillas Nike para correr (gama media) (USD)                                                            |
# | x47          | 1 par de zapatos de piel de vestir para hombre (USD)                                                               |
# | data_quality | 0 si Numbeo considera que se necesitan más colaboradores para mejorar la calidad de los datos; 1 en caso contrario |
#
#
# ##### **Dataset [Digital Nomad Index Circleloop](https://www.circleloop.com/nomadindex/)** ✅ ETL Completado
#
# **Estado:** Dataset limpio disponible en `digital-nomad-index-cicleloop-clean.csv`
#
# | Característica | Valor |
# |----------------|-------|
# | Filas | 85 países |
# | Columnas | 10 |
# | Moneda | USD (convertido desde GBP/EUR) |
#
# **Columnas finales (tras ETL):**
#
# | Columna | Tipo | Descripción |
# |---------|------|-------------|
# | `rank` | int | Posición en el ranking |
# | `country` | str | Nombre del país |
# | `broadband_speed_mbps` | float | Velocidad media de banda ancha fija (Mbps) |
# | `mobile_speed_mbps` | float | Velocidad media de internet móvil (Mbps) |
# | `broadband_cost` | float | Coste mensual de banda ancha (USD) |
# | `monthly_rent` | float | Alquiler mensual típico (USD) |
# | `happiness_index` | float | Índice de felicidad (World Happiness Report) |
# | `migrant_population_pct` | float | Porcentaje de población migrante |
# | `remote_jobs_searches` | int | Búsquedas de empleo remoto |
# | `digital_nomad_score` | float | Puntuación final de nomadismo digital |
#
# **Muestra de datos (valores en USD):**
#
# | rank | country     | broadband_speed_mbps | mobile_speed_mbps | broadband_cost | monthly_rent | happiness_index | digital_nomad_score |
# |------|-------------|---------------------|-------------------|----------------|--------------|-----------------|---------------------|
# | 1    | Canada      | 149.35              | 84.54             | 41.17          | 1045.00      | 7.23            | 74.35               |
# | 2    | UK          | 76.49               | 41.72             | 42.18          | 1019.70      | 7.17            | 63.43               |
# | 3    | Romania     | 188.55              | 41.48             | 9.63           | 357.50       | 6.12            | 62.28               |
# | 4    | Sweden      | 158.73              | 56.64             | 46.77          | 973.50       | 7.35            | 61.54               |
# | 5    | Denmark     | 179.81              | 66.68             | 56.96          | 1164.90      | 7.65            | 61.49               |
#
# **Nota:** La columna `Working Holidays Visa` fue eliminada durante el ETL por contener 100% valores nulos.

# %% [markdown]
# #### **4. Core del EDA: hipótesis primarias**
#
# El análisis se estructura en torno a tres hipótesis primarias centradas en viabilidad económica y conectividad digital. A partir de ellas, se incorporan hipótesis secundarias y exploratorias que enriquecen la comprensión del fenómeno, especialmente en términos de bienestar y contexto institucional.
#
# ¿Qué es una hipótesis primaria?
#
# Una hipótesis primaria en nuestro EDA debe cumplir al menos 3 de estos 4 criterios:
#
# 1. Responde directamente al problema central
# 2. Tiene alto impacto de negocio
# 3. Se apoya en variables clave y robustas
# 4. Conecta varios datasets (valor diferencial)
#
# 🔴 **Hipótesis 1 - Coste de vida medio**
#
# > Los países con mejor puntuación en el Digital Nomad Index presentan un coste de vida medio significativamente menor que la media global, especialmente en vivienda y servicios básicos.
#
# Cómo se validaría en EDA:
#
# - Unir datasets por países.
# - Comparar:
#     - Media de alquiler (variables x48 y x49).
#     - Coste mensual estimado (cesta básica).
# - Boxplots / distribuciones.
# - Comparación top 20% vs bottom 20%.
#
# 🔴 **Hipótesis 2 - Salarios vs coste de vida**
#
# > La relación entre salario local medio y coste de vida es más favorable en destinos populares para nómadas digitales que en el resto de países.
#
# Variables clave:
#
# - Salarios: variable x54.
# - Índice agregado de precios.
# - Digital Nomad Score.
# - Poder adquisitivo relativo = salario / coste de vida
#
# 🔴 **Hipótesis 3 — Conectividad determinante**
#
# > Los países con mayor velocidad y menor costo de internet tienen una puntuación de nomadismo significativamente mayor después de controlar por costo de vida total.
#
# 📌 Métricas a contrastar:
#
# - connectivity_index
# - circleloop_nomad_score

# %% [markdown]
# #### **6. Hipótesis secundarias (para enriquecer el EDA)**
#
# Estas no son obligatorias, pero elevan el nivel del análisis.
#
# 🟡 **Hipótesis 4 — Vivienda como factor crítico**
#
# > El coste del alquiler explica una mayor proporción de la variabilidad en la puntuación de nomadismo digital que el coste de alimentación o transporte.
#
# Objetivo:
#
# - Buscar posibles correlaciones entre precio de vivienda y buenos destinos para nomadismo digital.
#
# 🟡 **Hipótesis 5 — Infraestructura vs coste**
#
# > Algunos países presentan una infraestructura digital comparable a países desarrollados, pero con costes significativamente inferiores.
#
# Variables:
#
# - Internet: variables x38.
# - Coste agregado mensual
#
# Objetivo:
#
# - Quizás puede ser relevante para un nómada digital tener peor conectividad a nivel de internet pero donde el coste sea obstensiblemente menor.
#
#
# 🟡 **Hipótesis 6 — Bienestar social**
#
# > Existe una relación positiva entre el World Happiness Index y la puntuación de nomadismo, independientemente del coste de vida.
#
# Variables a comparar:
#
# - happiness_index
# - monthly_cost_estimate
# - circleloop_nomad_score
#
# Objetivo:
#
# - Buscar si el índice de felicidad global de los países con un referencia en la toma de decisión de destino de los nómadas digitales.
#
# 🟡 **Hipótesis 7 — Outliers positivos**
#
# > Existen países o ciudades que combinan un coste de vida bajo con una puntuación de nomadismo digital alta, funcionando como outliers positivos.
#
# Ideal para:
#
# - Scatter plots
# - Análisis por continente/región
#
# 🟡 **Hipótesis 8 — Seguridad como factor diferenciador** *(Hipótesis específicas del Dataset Movingto)*
#
# > Los destinos con mayor puntuación de seguridad tienen una puntuación de nomadismo digital significativamente mayor, incluso controlando por coste de vida.
#
# Variables:
#
# - `safety`
# - `overall_score`
# - `cost_of_living`
#
# Objetivo:
#
# - Determinar si la seguridad es un factor decisivo o secundario en la elección de destinos para los nómadas digitales.
#
# 🟡 **Hipótesis 9 — Accesibilidad de visa** *(Hipótesis específicas del Dataset Movingto)*
#
# > La facilidad para obtener visa de nómada digital correlaciona de forma positiva con el ranking de destinos, independientemente de otros factores económicos.
#
# Variables:
#
# - `visa_ease` (Movingto) — Score 0-100
# - `overall_score` (Movingto)
# - `taxes`, `tax_free_period` (información complementaria)
#
# Objetivo:
#
# - Evaluar el peso del factor burocrático/legal a la hora de elegir destino.

# %% [markdown]
# #### 8. Resultado esperado del EDA
#
# Al finalizar el EDA deberíamos poder responder con claridad:
#
# - Qué factores económicos sí importan en la elección de ciudad y páis.
# - Qué factores económicos o de otra índole no son tan relevantes.
# - Qué destinos están sobrevalorados.
# - Qué destinos están infraexplotados.
# - Qué variables explican mejor el fenómeno del nomadismo digital.
#
# #### 9. Cómo lo presentaría en un proyecto real
#
# Estructura final del análisis:
#
# 1. Contexto y problema ✅
# 2. Descripción y limpieza de datos ✅
# 3. Feature engineering (índices agregados)
# 4. Validación de hipótesis principales
# 5. Insights clave
# 6. Implicaciones de negocio
